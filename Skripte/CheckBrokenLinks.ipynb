# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def find_broken_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find_all('a')
    print(f"Links insgesamt: {len(links)}")
    
    broken_links = []
    for link in links:
        href = link.get('href')
        print(href)
        if href.startswith('http'):
            print("check")
            link_response = requests.head(href)
            if link_response.status_code >= 400:
                broken_links.append(href)
    
    return broken_links

# %%
url = 'https://sgm-abi.de'  # Ersetze dies mit der gewünschten URL
broken_links = find_broken_links(url)

print(f"Defekte Links: {len(broken_links)}")
for link in broken_links:
    print(link)
# Out:
# Links insgesamt: 84
# ./index.html
# ./Verein/Foerderverein.html
# ./Verein/Vorstand.html
# ./Verein/Rat.html
# ./Verein/FSJ.html
# ./Verein/Dribbling.html
# /teams/Trainingsinformationen.html
# /teams/A-Junioren.html
# /teams/B-Junioren.html
# /teams/B-Juniorinnen.html
# /teams/C-Junioren.html
# /teams/C-Juniorinnen.html
# /teams/D-Junioren.html
# /teams/D-Juniorinnen.html
# /teams/E-Junioren.html
# /teams/E-Juniorinnen.html
# /teams/F-Junioren.html
# /teams/G-Junioren.html
# ./news.html
# ./gallery.html
# mailto:abi-fussball@online.de
# https://www.wetter.de
# check
# https://www.fussball.de/mannschaft/sgm-spfr-widdern-spfr-widdern-wuerttemberg/-/saison/2223/team-id/02ILQ7RU48000000VS5489B2VVQ9C6A6
# check
# https://www.fussball.de/mannschaft/sgm-sc-ilsfeld-beilstein-abstatt-abi-sc-ilsfeld-wuerttemberg/-/saison/2223/team-id/02F0RK819O000000VS5489B2VUBVHUE0
# check
# ...
