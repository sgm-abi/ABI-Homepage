# %%
import requests
import csv
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
team_urls = pd.read_csv('Spiele_Links.csv')
idx = 0
print(len(team_urls))
url = team_urls['url'][idx]
response = requests.get(url)
# Out:
# 9

# %%
#BeautifulSoup HTML-Dokument aus dem Quelltext parsen
soup= BeautifulSoup(response.text, 'html.parser')

# %%
#Tabelle aus dem HTML-Dokument extrahieren
table = soup.find('div', {"id":'id-team-matchplan-table'})
#print(table)

# %%
team=team_urls['team'][idx]
#Datum und Liga auslesen (befindet sich in jeder 3. Zeile ab 2. Zeile)
for data in table.find_all('tbody'):
    rows = data.find_all('tr')
    dates = list()
    times = list()
    teams = list()
    for i in range(1,len(rows),3):
        #entfernt Sonderzeichen wie Zeilenumbruch (n) und Tab (t)
        date = rows[i].find('td', class_='column-date') #rows[i].text
        cleanString = re.sub(r'\ \|',',', date.text)
        cleanString = re.sub(r' ', '', cleanString)
        #removedSpace = re.sub(r'\t', '', removedSpace)
        splitted= cleanString.split(',')
        dates.append(splitted[1])
        times.append(splitted[2])
        teams.append(team)
        
df = pd.DataFrame(list(zip(dates,times,teams)),columns=['Datum','Zeit','Team'])
df
# Out:
#       Datum    Zeit Team
# 0  29.04.23   16:15    A
# 1  06.05.23   16:15    A
# 2  09.05.23   19:30    A
# 3  13.05.23   16:15    A
# 4  20.05.23   16:15    A
# 5  14.06.23   19:00    A
# 6  17.06.23   16:15    A

# %%
#Club und Logo auslesen (befindet sich in jeder 3. Zeile ab 3. Zeile)
for data in table.find_all('tbody'):
    rows = data.find_all('tr')
    club1 = list()
    club2 = list()
    for i in range(2,len(rows),3):
        #entfernt Sonderzeichen wie Zeilenumbruch (n) und Tab (t)
        removedSpace = re.sub(r'\n', '', rows[i].text)
        removedSpace = re.sub(r'\t', '', removedSpace)
        removedSpace = re.sub(r':', ';', removedSpace)
        splitted = removedSpace.split(';')
        club1.append(splitted[0].encode('ascii','ignore'))
        club2.append(str(splitted[1][0:-1]))

df.insert(len(df.columns), "Heim", club1)
df.insert(len(df.columns), "Gast", club2)

# %%
#Datum und Liga auslesen (befindet sich in jeder 3. Zeile ab 2. Zeile)
for data in table.find_all('tbody'):
    rows = data.find_all('tr')
    logos_home = list()
    logos_guest= list()
    for i in range(2,len(rows),3):
        #entfernt Sonderzeichen wie Zeilenumbruch (n) und Tab (t)
        logo = rows[i].find_all('div', class_="club-logo") #rows[i].text
        
        logo_link = re.findall(r'//(\S+)\">', str(logo))
        logos_home.append(logo_link[0])
        logos_guest.append(logo_link[1])
        
#found = re.search('AAA(.+?)ZZZ', string).group(1)        
df.insert(len(df.columns), 'KW', '')


df.insert(len(df.columns), 'Logo Heim', logos_home)
df.insert(len(df.columns), 'Logo Gast', logos_guest)

# %%
df
# Out:
#       Datum    Zeit Team                                    Heim  \
# 0  29.04.23   16:15    A                  SGM TSV Brettach KoBra
# 1  06.05.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 2  09.05.23   19:30    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 3  13.05.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 4  20.05.23   16:15    A                     Türkspor Neckarsulm
# 5  14.06.23   19:00    A                             TSV Talheim
# 6  17.06.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
#
#                                      Gast KW  \
# 0  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 1                SGM Neuenstadt Kochertal
# 2                             TSV Talheim
# 3                       Aramäer Heilbronn
# 4  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 5  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 6                  SGM TSV Brettach KoBra
#
#                                            Logo Heim  \
# 0  www.fussball.de/export.media/-/action/getLogo/...
# 1  www.fussball.de/export.media/-/action/getLogo/...
# 2  www.fussball.de/export.media/-/action/getLogo/...
# 3  www.fussball.de/export.media/-/action/getLogo/...
# 4  www.fussball.de/export.media/-/action/getLogo/...
# 5  www.fussball.de/export.media/-/action/getLogo/...
# 6  www.fussball.de/export.media/-/action/getLogo/...
#
#                                            Logo Gast
# 0  www.fussball.de/export.media/-/action/getLogo/...
# 1  www.fussball.de/export.media/-/action/getLogo/...
# 2  www.fussball.de/export.media/-/action/getLogo/...
# 3  www.fussball.de/export.media/-/action/getLogo/...
# 4  www.fussball.de/export.media/-/action/getLogo/...
# 5  www.fussball.de/export.media/-/action/getLogo/...
# 6  www.fussball.de/export.media/-/action/getLogo/...

# %%
links = table.find_all('a')
homeLinks = list();
guestLinks = list();
spielLinks = list();
for i in range(2, len(links),6):
    homeLinks.append(links[i].get('href'))
    guestLinks.append(links[i+1].get('href'))
    spielLinks.append(links[i+2].get('href'))
df.insert(len(df.columns), "home_link", homeLinks)
df.insert(len(df.columns), 'guest_link', guestLinks)
df.insert(len(df.columns), 'Spiel', spielLinks)
df
# Out:
#       Datum    Zeit Team                                    Heim  \
# 0  29.04.23   16:15    A                  SGM TSV Brettach KoBra
# 1  06.05.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 2  09.05.23   19:30    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 3  13.05.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 4  20.05.23   16:15    A                     Türkspor Neckarsulm
# 5  14.06.23   19:00    A                             TSV Talheim
# 6  17.06.23   16:15    A  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
#
#                                      Gast KW  \
# 0  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 1                SGM Neuenstadt Kochertal
# 2                             TSV Talheim
# 3                       Aramäer Heilbronn
# 4  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 5  SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 6                  SGM TSV Brettach KoBra
#
#                                            Logo Heim  \
# 0  www.fussball.de/export.media/-/action/getLogo/...
# 1  www.fussball.de/export.media/-/action/getLogo/...
# 2  www.fussball.de/export.media/-/action/getLogo/...
# 3  www.fussball.de/export.media/-/action/getLogo/...
# 4  www.fussball.de/export.media/-/action/getLogo/...
# 5  www.fussball.de/export.media/-/action/getLogo/...
# 6  www.fussball.de/export.media/-/action/getLogo/...
#
#                                            Logo Gast  \
# 0  www.fussball.de/export.media/-/action/getLogo/...
# 1  www.fussball.de/export.media/-/action/getLogo/...
# 2  www.fussball.de/export.media/-/action/getLogo/...
# 3  www.fussball.de/export.media/-/action/getLogo/...
# 4  www.fussball.de/export.media/-/action/getLogo/...
# 5  www.fussball.de/export.media/-/action/getLogo/...
# 6  www.fussball.de/export.media/-/action/getLogo/...
#
#                                            home_link  \
# 0  https://www.fussball.de/mannschaft/sgm-tsv-bre...
# 1  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 2  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 3  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 4  https://www.fussball.de/mannschaft/tuerkspor-n...
# 5  https://www.fussball.de/mannschaft/tsv-talheim...
# 6  https://www.fussball.de/mannschaft/sgm-sc-abst...
#
#                                           guest_link  \
# 0  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 1  https://www.fussball.de/mannschaft/sgm-neuenst...
# 2  https://www.fussball.de/mannschaft/tsv-talheim...
# 3  https://www.fussball.de/mannschaft/aramaeer-he...
# 4  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 5  https://www.fussball.de/mannschaft/sgm-sc-abst...
# 6  https://www.fussball.de/mannschaft/sgm-tsv-bre...
#
#                                                Spiel
# 0  https://www.fussball.de/spiel/sgm-tsv-brettach...
# 1  https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 2  https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 3  https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 4  https://www.fussball.de/spiel/tuerkspor-neckar...
# 5  https://www.fussball.de/spiel/tsv-talheim-sgm-...
# 6  https://www.fussball.de/spiel/sgm-sc-abstatt-b...

# %%
#merge columns to table
if (idx==0):
    df.to_csv('out.csv', index=False)
else:
    df.to_csv('out.csv', mode='a', index=False, header=False)
