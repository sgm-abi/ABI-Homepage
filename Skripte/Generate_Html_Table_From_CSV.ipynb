# %%
import csv
import pandas as pd
import codecs

# %%
df = pd.read_csv('out.csv', sep=",", encoding="utf-8")
df.head()
print(sorted(df.KW.unique()))
# Out:
# [16, 17, 18, 19, 20, 21, 23, 24, 25, 26]

# %%
#current calendar week -> add one to the current calendar week to get current week
kw = 17
filename = "Test_KW_" + str(kw) + ".html"
#extract data from current calendar week
kw_data = df.loc[df['KW']==kw]
#sort data by date and time
kw_data = kw_data.sort_values(by=['Datum','Zeit'])
kw_data
# Out:
#        Datum    Zeit       Team  KW  \
# 54  24.04.23   18:15         D2  17
# 21  24.04.23   18:30  B-J-innen  17
# 22  28.04.23   18:30  B-J-innen  17
# 43  29.04.23   10:30  C-J-innen  17
# 36  29.04.23   11:10         C2  17
# 55  29.04.23   11:10         D2  17
# 49  29.04.23   12:50         D1  17
# 29  29.04.23   13:00         C1  17
# 0   29.04.23   16:15          A  17
# 8   30.04.23   10:30         B1  17
#
#                                                  Heim  \
# 54                 SGM Nordhausen Unteres Zabergäu II
# 21             SGM SC Ilsfeld/​Beilstein/​Abstatt ABI
# 22                                        SV Sülzbach
# 43             SGM SC Ilsfeld/​Abstatt/​Beilstein ABI
# 36          SGM SC Ilsfeld/​Abstatt/​Beilstein ABI II
# 55    SGM Cleebronn/​Botenheim/​Eibensbach/​Stockheim
# 49                                    TSG Heilbronn I
# 29           SGM SC Ilsfeld/​Abstatt/​Beilstein ABI I
# 0                              SGM TSV Brettach KoBra
# 8   SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
#
#                                           Gast  \
# 54        SGM Ilsfeld-Abstatt-Beilstein ABI II
# 21                            SGM Spfr Widdern
# 22      SGM SC Ilsfeld/​Beilstein/​Abstatt ABI
# 43    SGM SV Onolzheim/​Honhardt/​Gründelhardt
# 36  SGM FV Wüstenrot /​ Neuhütten/​ Neulautern
# 55        SGM Ilsfeld-Abstatt-Beilstein ABI II
# 49        SGM Ilsfeld-Abstatt-Beilstein  ABI I
# 29                   Sport-Union Neckarsulm II
# 0       SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 8                      VfR Heilbronn 96/​18 II
#
#                                             Logo Heim  \
# 54  www.fussball.de/export.media/-/action/getLogo/...
# 21  www.fussball.de/export.media/-/action/getLogo/...
# 22  www.fussball.de/export.media/-/action/getLogo/...
# 43  www.fussball.de/export.media/-/action/getLogo/...
# 36  www.fussball.de/export.media/-/action/getLogo/...
# 55  www.fussball.de/export.media/-/action/getLogo/...
# 49  www.fussball.de/export.media/-/action/getLogo/...
# 29  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 8   www.fussball.de/export.media/-/action/getLogo/...
#
#                                             Logo Gast  \
# 54  www.fussball.de/export.media/-/action/getLogo/...
# 21  www.fussball.de/export.media/-/action/getLogo/...
# 22  www.fussball.de/export.media/-/action/getLogo/...
# 43  www.fussball.de/export.media/-/action/getLogo/...
# 36  www.fussball.de/export.media/-/action/getLogo/...
# 55  www.fussball.de/export.media/-/action/getLogo/...
# 49  www.fussball.de/export.media/-/action/getLogo/...
# 29  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 8   www.fussball.de/export.media/-/action/getLogo/...
#
#                                             home_link  \
# 54  https://www.fussball.de/mannschaft/sgm-nordhau...
# 21  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 22  https://www.fussball.de/mannschaft/sv-suelzbac...
# 43  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 36  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 55  https://www.fussball.de/mannschaft/sgm-cleebro...
# 49  https://www.fussball.de/mannschaft/tsg-heilbro...
# 29  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 0   https://www.fussball.de/mannschaft/sgm-tsv-bre...
# 8   https://www.fussball.de/mannschaft/sgm-tgv-ein...
#
#                                            guest_link  \
# 54  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 21  https://www.fussball.de/mannschaft/sgm-spfr-wi...
# 22  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 43  https://www.fussball.de/mannschaft/sgm-sv-onol...
# 36  https://www.fussball.de/mannschaft/sgm-fv-wues...
# 55  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 49  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 29  https://www.fussball.de/mannschaft/sport-union...
# 0   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 8   https://www.fussball.de/mannschaft/vfr-heilbro...
#
#                                                 Spiel
# 54  https://www.fussball.de/spiel/sgm-nordhausen-u...
# 21  https://www.fussball.de/spiel/sgm-sc-ilsfeld-b...
# 22  https://www.fussball.de/spiel/sv-suelzbach-i-s...
# 43  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 36  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 55  https://www.fussball.de/spiel/sgm-cleebronn-bo...
# 49  https://www.fussball.de/spiel/tsg-heilbronn-i-...
# 29  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 0   https://www.fussball.de/spiel/sgm-tsv-brettach...
# 8   https://www.fussball.de/spiel/sgm-tgv-eintrach...

# %%
#write head of table in html
table_head = "<table id=\"Spiele\">\n"
table_head += "\t<tr>\n"
table_head += "\t\t<th>Datum</th>\n"
table_head += "\t\t<th>Team</th>\n"
table_head += "\t\t<th>Heim</th>\n"
table_head += "\t\t<th>Gast</th>\n"
table_head += "\t\t<th>Ergebnis</th>\n"
table_head += "\t</tr>"
f = open(filename, "w")
f.write(table_head)
f.close()

# %%
f = open(filename, "a")
for ind in kw_data.index:
    html_line = "\t<tr>\n"
    html_line += "\t\t<td>" + df['Datum'][ind] + ", " + df['Zeit'][ind] + "</td>\n"
    html_line += "\t\t<td>" +  df['Team'][ind] + "</td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['guest_link'][ind] + "\" target=\"_blank\">" +  df['Gast'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['Spiel'][ind] + "\" target=\"_blank\">link</a>" + "</td>\n"
    html_line += "\t</tr>\n"
    
    f.write(html_line)
f.write("</table>")
f.close()

# %%
str(df['Gast'][3].replace('\u200b',''))
# Out:
# 'Aramäer Heilbronn'
