# %%
import csv
import pandas as pd
import codecs
import re

# %%
df = pd.read_csv('out_new.csv', sep=",", encoding="utf-8")
df.head()
print(sorted(df.KW.unique()))
# Out:
# [19, 20, 21, 23, 24, 25, 26]

# %%
#current calendar week -> add one to the current calendar week to get current week
kw = 24
filename = "Test_KW_" + str(kw) + ".html"
print(filename)
#extract data from current calendar week
kw_data = df.loc[df['KW']==kw]
#sort data by date and time
kw_data = kw_data.sort_values(by=['Datum','Zeit'])
kw_data['Heim'] = kw_data['Heim'].replace(r'SGM.*ABI.*','SGM ABI', regex=True)
kw_data['Gast'] = kw_data['Gast'].replace(r'SGM.*ABI.*','SGM ABI', regex=True)
kw_data
# Out:
# Test_KW_24.html
#        Datum    Zeit       Team  KW                              Heim  \
# 2   14.06.23   19:00          A  24                       TSV Talheim
# 6   14.06.23   19:00         B1  24                           SGM ABI
# 11  14.06.23   19:00         B2  24     SGM  Frauenzimmern/​Güglingen
# 23  14.06.23   19:00         C2  24                           SGM ABI
# 16  16.06.23   18:30  B-J-innen  24                           SGM ABI
# 24  17.06.23   11:10         C2  24         SGM Oedheim/​Dahenfeld II
# 31  17.06.23   11:10         D2  24                       SC Amorbach
# 20  17.06.23   13:00         C1  24  SGM Spfr. Bühlerzell/​Bühlertann
# 3   17.06.23   16:15          A  24                           SGM ABI
# 7   18.06.23   10:30         B1  24           VfR Heilbronn 96/​18 II
# 12  18.06.23   10:30         B2  24                           SGM ABI
#
#                                  Gast  \
# 2                             SGM ABI
# 6           Sport-Union Neckarsulm II
# 11                            SGM ABI
# 23  SGM TSV Neudenau Unteres Jagsttal
# 16                        SV Sülzbach
# 24                            SGM ABI
# 31                            SGM ABI
# 20                            SGM ABI
# 3              SGM TSV Brettach KoBra
# 7                             SGM ABI
# 12                  Aramäer Heilbronn
#
#                                             Logo Heim  \
# 2   www.fussball.de/export.media/-/action/getLogo/...
# 6   www.fussball.de/export.media/-/action/getLogo/...
# 11  www.fussball.de/export.media/-/action/getLogo/...
# 23  www.fussball.de/export.media/-/action/getLogo/...
# 16  www.fussball.de/export.media/-/action/getLogo/...
# 24  www.fussball.de/export.media/-/action/getLogo/...
# 31  www.fussball.de/export.media/-/action/getLogo/...
# 20  www.fussball.de/export.media/-/action/getLogo/...
# 3   www.fussball.de/export.media/-/action/getLogo/...
# 7   www.fussball.de/export.media/-/action/getLogo/...
# 12  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             Logo Gast  \
# 2   www.fussball.de/export.media/-/action/getLogo/...
# 6   www.fussball.de/export.media/-/action/getLogo/...
# 11  www.fussball.de/export.media/-/action/getLogo/...
# 23  www.fussball.de/export.media/-/action/getLogo/...
# 16  www.fussball.de/export.media/-/action/getLogo/...
# 24  www.fussball.de/export.media/-/action/getLogo/...
# 31  www.fussball.de/export.media/-/action/getLogo/...
# 20  www.fussball.de/export.media/-/action/getLogo/...
# 3   www.fussball.de/export.media/-/action/getLogo/...
# 7   www.fussball.de/export.media/-/action/getLogo/...
# 12  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             home_link  \
# 2   https://www.fussball.de/mannschaft/tsv-talheim...
# 6   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 11  https://www.fussball.de/mannschaft/sgm-frauenz...
# 23  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 16  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 24  https://www.fussball.de/mannschaft/sgm-oedheim...
# 31  https://www.fussball.de/mannschaft/sc-amorbach...
# 20  https://www.fussball.de/mannschaft/sgm-spfr-bu...
# 3   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 7   https://www.fussball.de/mannschaft/vfr-heilbro...
# 12  https://www.fussball.de/mannschaft/sgm-tgv-ein...
#
#                                            guest_link  \
# 2   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 6   https://www.fussball.de/mannschaft/sport-union...
# 11  https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 23  https://www.fussball.de/mannschaft/sgm-tsv-neu...
# 16  https://www.fussball.de/mannschaft/sv-suelzbac...
# 24  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 31  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 20  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 3   https://www.fussball.de/mannschaft/sgm-tsv-bre...
# 7   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 12  https://www.fussball.de/mannschaft/aramaeer-he...
#
#                                                 Spiel
# 2   https://www.fussball.de/spiel/tsv-talheim-sgm-...
# 6   https://www.fussball.de/spiel/sgm-tgv-eintrach...
# 11  https://www.fussball.de/spiel/sgm-frauenzimmer...
# 23  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 16  https://www.fussball.de/spiel/sgm-sc-ilsfeld-b...
# 24  https://www.fussball.de/spiel/sgm-oedheim-dahe...
# 31  https://www.fussball.de/spiel/sc-amorbach-sgm-...
# 20  https://www.fussball.de/spiel/sgm-spfr-buehler...
# 3   https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 7   https://www.fussball.de/spiel/vfr-heilbronn-96...
# 12  https://www.fussball.de/spiel/sgm-tgv-eintrach...

# %%
#write head of table in html
table_head = "<table id=\"Spiele\">\n"
table_head += "\t<tr>\n"
table_head += "\t\t<th>Datum</th>\n"
table_head += "\t\t<th>Team</th>\n"
table_head += "\t\t<th>Heim</th>\n"
table_head += "\t\t<th>Gast</th>\n"
table_head += "\t\t<th>Ergebnis</th>\n"
table_head += "\t</tr>"
f = open(filename, "w")
f.write(table_head)
f.close()

# %%
f = open(filename, "a")
for ind in kw_data.index:
    html_line = "\t<tr>\n"
    html_line += "\t\t<td>" + kw_data['Datum'][ind] + ", " + kw_data['Zeit'][ind] + "</td>\n"
    html_line += "\t\t<td>" +  kw_data['Team'][ind] + "</td>\n"
    if kw_data['Heim'][ind]== "SGM ABI":
        print('blah')
        html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\" class=\"ABI\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    else:
        html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\" class=\"ABI\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['guest_link'][ind] + "\" target=\"_blank\">" +  df['Gast'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['Spiel'][ind] + "\" target=\"_blank\">link</a>" + "</td>\n"
    html_line += "\t</tr>\n"
    
    f.write(html_line)
f.write("</table>")
f.close()

# %%
str(df['Gast'][3].replace('SGM','blah'))
# Out:
# 'blah TSV Brettach KoBra'
