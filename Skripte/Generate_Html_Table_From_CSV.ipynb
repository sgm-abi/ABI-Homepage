# %%
import csv
import pandas as pd
import codecs
import re

# %%
df = pd.read_csv('out_new.csv', sep=",", encoding="utf-8")
df.head()
print(sorted(df.KW.unique()))
# Out:
# [19, 20, 21, 23, 24, 25, 26]

# %%
#current calendar week -> add one to the current calendar week to get current week
kw = 20
filename = "Test_KW_" + str(kw) + ".html"
#extract data from current calendar week
kw_data = df.loc[df['KW']==kw]
#sort data by date and time
kw_data = kw_data.sort_values(by=['Datum','Zeit'])
kw_data.replace(to_replace=r'.*ABI.*', value='new', regex=True)
kw_data
# Out:
#        Datum    Zeit       Team  KW  \
# 9   18.05.23   14:30         B2  20
# 14  19.05.23   18:30  B-J-innen  20
# 30  20.05.23   09:30         D2  20
# 29  20.05.23   11:10         D1  20
# 18  20.05.23   13:00         C1  20
# 22  20.05.23   14:30         C2  20
# 1   20.05.23   16:15          A  20
# 5   21.05.23   10:30         B1  20
# 10  21.05.23   10:30         B2  20
#
#                                                  Heim  \
# 9   SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
# 14                                TSV Langenbeutingen
# 30               SGM Ilsfeld-Abstatt-Beilstein ABI II
# 29               SGM Ilsfeld-Abstatt-Beilstein  ABI I
# 18                            FSV Friedrichshaller SV
# 22                                      SSV Auenstein
# 1                                 Türkspor Neckarsulm
# 5                                            TV Flein
# 10  SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
#
#                                                  Gast  \
# 9                              VfR Heilbronn 96/​18 I
# 14             SGM SC Ilsfeld/​Beilstein/​Abstatt ABI
# 30                                        TV Flein II
# 29            SGM FV Wüstenrot/​Neuhütten/​Neulautern
# 18           SGM SC Ilsfeld/​Abstatt/​Beilstein ABI I
# 22          SGM SC Ilsfeld/​Abstatt/​Beilstein ABI II
# 1              SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 5   SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
# 10                                 SC Böckingen (9er)
#
#                                             Logo Heim  \
# 9   www.fussball.de/export.media/-/action/getLogo/...
# 14  www.fussball.de/export.media/-/action/getLogo/...
# 30  www.fussball.de/export.media/-/action/getLogo/...
# 29  www.fussball.de/export.media/-/action/getLogo/...
# 18  www.fussball.de/export.media/-/action/getLogo/...
# 22  www.fussball.de/export.media/-/action/getLogo/...
# 1   www.fussball.de/export.media/-/action/getLogo/...
# 5   www.fussball.de/export.media/-/action/getLogo/...
# 10  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             Logo Gast  \
# 9   www.fussball.de/export.media/-/action/getLogo/...
# 14  www.fussball.de/export.media/-/action/getLogo/...
# 30  www.fussball.de/export.media/-/action/getLogo/...
# 29  www.fussball.de/export.media/-/action/getLogo/...
# 18  www.fussball.de/export.media/-/action/getLogo/...
# 22  www.fussball.de/export.media/-/action/getLogo/...
# 1   www.fussball.de/export.media/-/action/getLogo/...
# 5   www.fussball.de/export.media/-/action/getLogo/...
# 10  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             home_link  \
# 9   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 14  https://www.fussball.de/mannschaft/tsv-langenb...
# 30  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 29  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 18  https://www.fussball.de/mannschaft/fsv-friedri...
# 22  https://www.fussball.de/mannschaft/ssv-auenste...
# 1   https://www.fussball.de/mannschaft/tuerkspor-n...
# 5   https://www.fussball.de/mannschaft/tv-flein-tv...
# 10  https://www.fussball.de/mannschaft/sgm-tgv-ein...
#
#                                            guest_link  \
# 9   https://www.fussball.de/mannschaft/vfr-heilbro...
# 14  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 30  https://www.fussball.de/mannschaft/tv-flein-ii...
# 29  https://www.fussball.de/mannschaft/sgm-fv-wues...
# 18  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 22  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 1   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 5   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 10  https://www.fussball.de/mannschaft/sc-boecking...
#
#                                                 Spiel
# 9   https://www.fussball.de/spiel/sgm-tgv-eintrach...
# 14  https://www.fussball.de/spiel/tsv-langenbeutin...
# 30  https://www.fussball.de/spiel/sgm-ilsfeld-abst...
# 29  https://www.fussball.de/spiel/sgm-ilsfeld-abst...
# 18  https://www.fussball.de/spiel/fsv-friedrichsha...
# 22  https://www.fussball.de/spiel/ssv-auenstein-sg...
# 1   https://www.fussball.de/spiel/tuerkspor-neckar...
# 5   https://www.fussball.de/spiel/tv-flein-sgm-tgv...
# 10  https://www.fussball.de/spiel/sgm-tgv-eintrach...

# %%
#write head of table in html
table_head = "<table id=\"Spiele\">\n"
table_head += "\t<tr>\n"
table_head += "\t\t<th>Datum</th>\n"
table_head += "\t\t<th>Team</th>\n"
table_head += "\t\t<th>Heim</th>\n"
table_head += "\t\t<th>Gast</th>\n"
table_head += "\t\t<th>Ergebnis</th>\n"
table_head += "\t</tr>"
f = open(filename, "w")
f.write(table_head)
f.close()

# %%
f = open(filename, "a")
for ind in kw_data.index:
    html_line = "\t<tr>\n"
    html_line += "\t\t<td>" + df['Datum'][ind] + ", " + df['Zeit'][ind] + "</td>\n"
    html_line += "\t\t<td>" +  df['Team'][ind] + "</td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['guest_link'][ind] + "\" target=\"_blank\">" +  df['Gast'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['Spiel'][ind] + "\" target=\"_blank\">link</a>" + "</td>\n"
    html_line += "\t</tr>\n"
    
    f.write(html_line)
f.write("</table>")
f.close()

# %%
str(df['Gast'][3].replace('SGM','blah'))
# Out:
# 'blah TSV Brettach KoBra'
