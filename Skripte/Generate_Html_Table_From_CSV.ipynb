# %%
import csv
import pandas as pd
import codecs
import re

# %%
df = pd.read_csv('out_new.csv', sep=",", encoding="utf-8")
df.head()
print(sorted(df.KW.unique()))
# Out:
# [19, 20, 21, 23, 24, 25, 26]

# %%
#current calendar week -> add one to the current calendar week to get current week
kw = 19
filename = "Test_KW_" + str(kw) + ".html"
print(filename)
#extract data from current calendar week
kw_data = df.loc[df['KW']==kw]
#sort data by date and time
kw_data = kw_data.sort_values(by=['Datum','Zeit'])
kw_data['Heim'] = kw_data['Heim'].replace(r'SGM.*ABI.*','SGM ABI', regex=True)
kw_data['Gast'] = kw_data['Gast'].replace(r'SGM.*ABI.*','SGM ABI', regex=True)
kw_data
# Out:
# Test_KW_19.html
#        Datum    Zeit       Team  KW                       Heim  \
# 13  12.05.23   18:30  B-J-innen  19                    SGM ABI
# 25  13.05.23   10:30  C-J-innen  19                    SGM ABI
# 21  13.05.23   11:10         C2  19                    SGM ABI
# 28  13.05.23   11:10         D1  19  SGM TSV Erlenbach EbErG I
# 17  13.05.23   13:00         C1  19                    SGM ABI
# 0   13.05.23   16:15          A  19                    SGM ABI
# 4   14.05.23   10:30         B1  19                    SGM ABI
# 8   14.05.23   10:30         B2  19              Spfr. Lauffen
#
#                                                  Gast  \
# 13                                  TGV Dürrenzimmern
# 25                                        SV Morsbach
# 21                           SV Heilbronn am Leinbach
# 28                                            SGM ABI
# 17  SGM FC Honhardt/​Obersontheim/​Gründel.-Obersp...
# 0                                   Aramäer Heilbronn
# 4                           SGM TSV Hardthausen KoBra
# 8                                             SGM ABI
#
#                                             Logo Heim  \
# 13  www.fussball.de/export.media/-/action/getLogo/...
# 25  www.fussball.de/export.media/-/action/getLogo/...
# 21  www.fussball.de/export.media/-/action/getLogo/...
# 28  www.fussball.de/export.media/-/action/getLogo/...
# 17  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 4   www.fussball.de/export.media/-/action/getLogo/...
# 8   www.fussball.de/export.media/-/action/getLogo/...
#
#                                             Logo Gast  \
# 13  www.fussball.de/export.media/-/action/getLogo/...
# 25  www.fussball.de/export.media/-/action/getLogo/...
# 21  www.fussball.de/export.media/-/action/getLogo/...
# 28  www.fussball.de/export.media/-/action/getLogo/...
# 17  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 4   www.fussball.de/export.media/-/action/getLogo/...
# 8   www.fussball.de/export.media/-/action/getLogo/...
#
#                                             home_link  \
# 13  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 25  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 21  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 28  https://www.fussball.de/mannschaft/sgm-tsv-erl...
# 17  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 0   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 4   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 8   https://www.fussball.de/mannschaft/spfr-lauffe...
#
#                                            guest_link  \
# 13  https://www.fussball.de/mannschaft/tgv-duerren...
# 25  https://www.fussball.de/mannschaft/sv-morsbach...
# 21  https://www.fussball.de/mannschaft/sv-heilbron...
# 28  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 17  https://www.fussball.de/mannschaft/sgm-fc-honh...
# 0   https://www.fussball.de/mannschaft/aramaeer-he...
# 4   https://www.fussball.de/mannschaft/sgm-tsv-har...
# 8   https://www.fussball.de/mannschaft/sgm-tgv-ein...
#
#                                                 Spiel
# 13  https://www.fussball.de/spiel/sgm-sc-ilsfeld-b...
# 25  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 21  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 28  https://www.fussball.de/spiel/sgm-tsv-erlenbac...
# 17  https://www.fussball.de/spiel/sgm-sc-ilsfeld-a...
# 0   https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 4   https://www.fussball.de/spiel/sgm-tgv-eintrach...
# 8   https://www.fussball.de/spiel/spfr-lauffen-sgm...

# %%
#write head of table in html
table_head = "<table id=\"Spiele\">\n"
table_head += "\t<tr>\n"
table_head += "\t\t<th>Datum</th>\n"
table_head += "\t\t<th>Team</th>\n"
table_head += "\t\t<th>Heim</th>\n"
table_head += "\t\t<th>Gast</th>\n"
table_head += "\t\t<th>Ergebnis</th>\n"
table_head += "\t</tr>"
f = open(filename, "w")
f.write(table_head)
f.close()

# %%
f = open(filename, "a")
for ind in kw_data.index:
    html_line = "\t<tr>\n"
    html_line += "\t\t<td>" + kw_data['Datum'][ind] + ", " + kw_data['Zeit'][ind] + "</td>\n"
    html_line += "\t\t<td>" +  kw_data['Team'][ind] + "</td>\n"
    if kw_data['Heim'][ind]== "SGM ABI":
        print('blah')
        html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\" class=\"ABI\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    else:
        html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\" class=\"ABI\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['guest_link'][ind] + "\" target=\"_blank\">" +  df['Gast'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['Spiel'][ind] + "\" target=\"_blank\">link</a>" + "</td>\n"
    html_line += "\t</tr>\n"
    
    f.write(html_line)
f.write("</table>")
f.close()
# Out:
# blah
# blah
# blah
# blah
# blah
# blah

# %%
str(df['Gast'][3].replace('SGM','blah'))
# Out:
# 'blah TSV Brettach KoBra'
