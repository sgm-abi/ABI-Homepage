# %%
import csv
import pandas as pd
import codecs
import re

# %%
df = pd.read_csv('out.csv', sep=",", encoding="utf-8")
df.head()
print(sorted(df.KW.unique()))
# Out:
# [18, 19, 20, 21, 23, 24, 25, 26]

# %%
#current calendar week -> add one to the current calendar week to get current week
kw = 18
filename = "Test_KW_" + str(kw) + ".html"
#extract data from current calendar week
kw_data = df.loc[df['KW']==kw]
#sort data by date and time
kw_data = kw_data.sort_values(by=['Datum','Zeit'])
kw_data.replace(to_replace=r'.*ABI.*', value='new', regex=True)
kw_data
# Out:
#        Datum    Zeit       Team  KW  \
# 11  05.05.23   18:30         B2  18
# 18  05.05.23   18:30  B-J-innen  18
# 40  06.05.23   09:30         D2  18
# 37  06.05.23   11:10         D1  18
# 28  06.05.23   13:00         C2  18
# 33  06.05.23   14:00  C-J-innen  18
# 23  06.05.23   15:15         C1  18
# 0   06.05.23   16:15          A  18
# 6   07.05.23   10:30         B1  18
# 12  07.05.23   10:30         B2  18
#
#                                                  Heim  \
# 11                                 SC Oberes Zabergäu
# 18             SGM SC Ilsfeld/​Beilstein/​Abstatt ABI
# 40               SGM Ilsfeld-Abstatt-Beilstein ABI II
# 37               SGM Ilsfeld-Abstatt-Beilstein  ABI I
# 28                                  VfL Obereisesheim
# 33                                   Spvgg Oedheim II
# 23                                     TSV Ilshofen I
# 0              SGM SC Abstatt/​Beilstein/​Ilsfeld ABI
# 6                  SGM Dürrenzimmern Unteres Zabergäu
# 12  SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
#
#                                                  Gast  \
# 11  SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
# 18                         SGM TSV Talheim/​Heilbronn
# 40                          SGM Dahenfeld/​Oedheim II
# 37                              Türkspor Neckarsulm I
# 28          SGM SC Ilsfeld/​Abstatt/​Beilstein ABI II
# 33             SGM SC Ilsfeld/​Abstatt/​Beilstein ABI
# 23           SGM SC Ilsfeld/​Abstatt/​Beilstein ABI I
# 0                            SGM Neuenstadt Kochertal
# 6   SGM TGV Eintracht Beilstein/​Abstatt/​Ilsfeld ...
# 12                          SGM Kirchhausen/​Biberach
#
#                                             Logo Heim  \
# 11  www.fussball.de/export.media/-/action/getLogo/...
# 18  www.fussball.de/export.media/-/action/getLogo/...
# 40  www.fussball.de/export.media/-/action/getLogo/...
# 37  www.fussball.de/export.media/-/action/getLogo/...
# 28  www.fussball.de/export.media/-/action/getLogo/...
# 33  www.fussball.de/export.media/-/action/getLogo/...
# 23  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 6   www.fussball.de/export.media/-/action/getLogo/...
# 12  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             Logo Gast  \
# 11  www.fussball.de/export.media/-/action/getLogo/...
# 18  www.fussball.de/export.media/-/action/getLogo/...
# 40  www.fussball.de/export.media/-/action/getLogo/...
# 37  www.fussball.de/export.media/-/action/getLogo/...
# 28  www.fussball.de/export.media/-/action/getLogo/...
# 33  www.fussball.de/export.media/-/action/getLogo/...
# 23  www.fussball.de/export.media/-/action/getLogo/...
# 0   www.fussball.de/export.media/-/action/getLogo/...
# 6   www.fussball.de/export.media/-/action/getLogo/...
# 12  www.fussball.de/export.media/-/action/getLogo/...
#
#                                             home_link  \
# 11  https://www.fussball.de/mannschaft/sc-oberes-z...
# 18  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 40  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 37  https://www.fussball.de/mannschaft/sgm-ilsfeld...
# 28  https://www.fussball.de/mannschaft/vfl-obereis...
# 33  https://www.fussball.de/mannschaft/spvgg-oedhe...
# 23  https://www.fussball.de/mannschaft/tsv-ilshofe...
# 0   https://www.fussball.de/mannschaft/sgm-sc-abst...
# 6   https://www.fussball.de/mannschaft/sgm-duerren...
# 12  https://www.fussball.de/mannschaft/sgm-tgv-ein...
#
#                                            guest_link  \
# 11  https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 18  https://www.fussball.de/mannschaft/sgm-tsv-tal...
# 40  https://www.fussball.de/mannschaft/sgm-dahenfe...
# 37  https://www.fussball.de/mannschaft/tuerkspor-n...
# 28  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 33  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 23  https://www.fussball.de/mannschaft/sgm-sc-ilsf...
# 0   https://www.fussball.de/mannschaft/sgm-neuenst...
# 6   https://www.fussball.de/mannschaft/sgm-tgv-ein...
# 12  https://www.fussball.de/mannschaft/sgm-kirchha...
#
#                                                 Spiel
# 11  https://www.fussball.de/spiel/sc-oberes-zaberg...
# 18  https://www.fussball.de/spiel/sgm-sc-ilsfeld-b...
# 40  https://www.fussball.de/spiel/sgm-ilsfeld-abst...
# 37  https://www.fussball.de/spiel/sgm-ilsfeld-abst...
# 28  https://www.fussball.de/spiel/vfl-obereiseshei...
# 33  https://www.fussball.de/spiel/spvgg-oedheim-ii...
# 23  https://www.fussball.de/spiel/tsv-ilshofen-i-s...
# 0   https://www.fussball.de/spiel/sgm-sc-abstatt-b...
# 6   https://www.fussball.de/spiel/sgm-duerrenzimme...
# 12  https://www.fussball.de/spiel/sgm-tgv-eintrach...

# %%
#write head of table in html
table_head = "<table id=\"Spiele\">\n"
table_head += "\t<tr>\n"
table_head += "\t\t<th>Datum</th>\n"
table_head += "\t\t<th>Team</th>\n"
table_head += "\t\t<th>Heim</th>\n"
table_head += "\t\t<th>Gast</th>\n"
table_head += "\t\t<th>Ergebnis</th>\n"
table_head += "\t</tr>"
f = open(filename, "w")
f.write(table_head)
f.close()

# %%
f = open(filename, "a")
for ind in kw_data.index:
    html_line = "\t<tr>\n"
    html_line += "\t\t<td>" + df['Datum'][ind] + ", " + df['Zeit'][ind] + "</td>\n"
    html_line += "\t\t<td>" +  df['Team'][ind] + "</td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['home_link'][ind] + "\" target=\"_blank\">" +  df['Heim'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['guest_link'][ind] + "\" target=\"_blank\">" +  df['Gast'][ind].replace('\u200b','') + "</a></td>\n"
    html_line += "\t\t<td>" + "<a href=\"" + df['Spiel'][ind] + "\" target=\"_blank\">link</a>" + "</td>\n"
    html_line += "\t</tr>\n"
    
    f.write(html_line)
f.write("</table>")
f.close()

# %%
str(df['Gast'][3].replace('SGM','blah'))
# Out:
# 'blah SC Abstatt/\u200bBeilstein/\u200bIlsfeld ABI'
